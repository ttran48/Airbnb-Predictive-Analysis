# %% [markdown]
# # Introduction
#
# In this challenge, we are given a list of users along with their demographics, web session records, and some summary statistics. We are asked to predict which country a new user's first booking destination will be. All the users in this dataset are from the USA.
#
# There are 12 possible outcomes of the destination country: 'US', 'FR', 'CA', 'GB', 'ES', 'IT', 'PT', 'NL','DE', 'AU', 'NDF' (no destination found), and 'other'. Note that 'NDF' is different from 'other' because 'other' means there was a booking, but is to a country not included in the list, while 'NDF' means there wasn't a booking.
#
# The training and test sets are split by dates. In the test set, we will predict all the new users with first activities after 7/1/2014. In the sessions dataset, the data only dates back to 1/1/2014, while the users dataset dates back to 2010.
#
# The datasets are:
#
# * age_gender_bkts.csv
# * countries.csv
# * sample_submission_NDF.csv
# * sessions.csv
# * test_users.csv
# * train_users2.csv
#
# We will go through the following steps:
# * Fetch Airbnb data from https://www.kaggle.com/c/airbnb-recruiting-new-user-bookings/data
# * Merge the test_users.csv and train_users2.csv
# * Clean the data
# * Parse the data
# * Collect the data in a panda dataframe
# * Display the data
# * Explore the data
# * Build Predictive Model
#
# We will also show the different sub-steps that can be taken to reach the presented solution.
#
# As we begin the study, we first need to ensure that the datasets are clean and that all irrelevant parts are removed or filled correctly.

# %%
import numpy as np # library for working with Arrays
import pandas as pd # makes working with data tables easier
import matplotlib.pyplot as plt # module for plotting
import seaborn as sns #

# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

# Load the data into DataFrames
train_users = pd.read_csv("train_users_2.csv") # Use the training set to build model
test_users = pd.read_csv("test_users.csv") # Use the test set to validate model

# %% [markdown]
# We checked both train_users and test_users to understand the content of the data.
# The results of the analysis are as followed:
# * The attributes of both data sets are similar
# * There is 1 additional column that is different in the train_users.csv data set titled country_destination
# * There are many irrelevant parts that needs to be resolved in the data sets

# %%
train_users.shape
# Out:
# (213451, 16)

# %%
test_users.shape
# Out:
# (62096, 16)

# %%
train_users
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28          20090319043255
# 1       820tgsjxq7           2011-05-25          20090523174809
# 2       4ft3gnwmtx           2010-09-28          20090609231247
# 3       bjjt8pjhuk           2011-12-05          20091031060129
# 4       87mebub9p4           2010-09-14          20091208061105
# 5       osr2jwljor           2010-01-01          20100101215619
# 6       lsw9q7uk0j           2010-01-02          20100102012558
# 7       0d01nltbrs           2010-01-03          20100103191905
# 8       a1vcnhxeij           2010-01-04          20100104004211
# 9       6uh8zyj2gn           2010-01-04          20100104023758
# 10      yuuqmid2rp           2010-01-04          20100104194251
# 11      om1ss59ys8           2010-01-05          20100105051812
# 12      k6np330cm1           2010-01-05          20100105060859
# 13      dy3rgx56cu           2010-01-05          20100105083259
# 14      ju3h98ch3w           2010-01-07          20100107055820
# 15      v4d5rl22px           2010-01-07          20100107204555
# 16      2dwbwkx056           2010-01-07          20100107215125
# 17      frhre329au           2010-01-07          20100107224625
# 18      cxlg85pg1r           2010-01-08          20100108015641
# 19      gdka1q5ktd           2010-01-10          20100110010817
# 20      qdubonn3uk           2010-01-10          20100110152120
# 21      qsibmuz9sx           2010-01-10          20100110220941
# 22      80f7dwscrn           2010-01-11          20100111031438
# 23      jha93x042q           2010-01-11          20100111224015
# 24      7i49vnuav6           2010-01-11          20100111230808
# 25      al8bcetz0g           2010-01-12          20100112131444
# 26      bjg0m5otl3           2010-01-12          20100112155420
# 27      hfrl5gle36           2010-01-12          20100112205949
# 28      tp6x3md0n4           2010-01-13          20100113044650
# 29      hql77nu2lk           2010-01-13          20100113064333
# ...            ...                  ...                     ...
# 213421  c98s3h7kgj           2014-06-30          20140630231137
# 213422  ytmpiwb8hj           2014-06-30          20140630231246
# 213423  3dx1jk6yk2           2014-06-30          20140630231548
# 213424  hcfj07iowv           2014-06-30          20140630231859
# 213425  l1f71f9vsj           2014-06-30          20140630232119
# 213426  15bj4ahmhf           2014-06-30          20140630232331
# 213427  qwpybxfjdl           2014-06-30          20140630232539
# 213428  k4t61wuvyq           2014-06-30          20140630232634
# 213429  mhh7b52z44           2014-06-30          20140630232712
# 213430  79wk7k2k5t           2014-06-30          20140630233132
# 213431  ftwmocvwlq           2014-06-30          20140630233203
# 213432  rg7ayg1tob           2014-06-30          20140630233224
# 213433  2f24umzkuv           2014-06-30          20140630233427
# 213434  or77n2ojuj           2014-06-30          20140630233640
# 213435  0a5bnb9bs4           2014-06-30          20140630233851
# 213436  6fzrn49sfn           2014-06-30          20140630234113
# 213437  r0jq0devgy           2014-06-30          20140630234243
# 213438  v5lq9bj8gv           2014-06-30          20140630234429
# 213439  msucfwmlzc           2014-06-30          20140630234729
# 213440  04y8115avm           2014-06-30          20140630234933
# 213441  omlc9iku7t           2014-06-30          20140630235151
# 213442  rf0ay567js           2014-06-30          20140630235309
# 213443  0k26r3mir0           2014-06-30          20140630235340
# 213444  40o1ivh6cb           2014-06-30          20140630235352
# 213445  qbxza0xojf           2014-06-30          20140630235547
# 213446  zxodksqpep           2014-06-30          20140630235636
# 213447  mhewnxesx9           2014-06-30          20140630235719
# 213448  6o3arsjbb4           2014-06-30          20140630235754
# 213449  jh95kwisub           2014-06-30          20140630235822
# 213450  nw9fwlyb5f           2014-06-30          20140630235824
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN  -unknown-   NaN      facebook            0
# 1                     NaN       MALE  38.0      facebook            0
# 2              2010-08-02     FEMALE  56.0         basic            3
# 3              2012-09-08     FEMALE  42.0      facebook            0
# 4              2010-02-18  -unknown-  41.0         basic            0
# 5              2010-01-02  -unknown-   NaN         basic            0
# 6              2010-01-05     FEMALE  46.0         basic            0
# 7              2010-01-13     FEMALE  47.0         basic            0
# 8              2010-07-29     FEMALE  50.0         basic            0
# 9              2010-01-04  -unknown-  46.0         basic            0
# 10             2010-01-06     FEMALE  36.0         basic            0
# 11                    NaN     FEMALE  47.0         basic            0
# 12             2010-01-18  -unknown-   NaN         basic            0
# 13                    NaN     FEMALE  37.0         basic            0
# 14                    NaN     FEMALE  36.0         basic            0
# 15             2010-01-08     FEMALE  33.0         basic            0
# 16                    NaN  -unknown-   NaN         basic            0
# 17             2010-01-09  -unknown-  31.0         basic            0
# 18                    NaN  -unknown-   NaN         basic            0
# 19             2010-01-10     FEMALE  29.0         basic            0
# 20             2010-01-18  -unknown-   NaN         basic            0
# 21             2010-01-11       MALE  30.0         basic            0
# 22             2010-01-11  -unknown-  40.0         basic            0
# 23                    NaN  -unknown-   NaN         basic            0
# 24                    NaN     FEMALE  40.0         basic            0
# 25             2010-01-15     FEMALE  26.0         basic            0
# 26                    NaN  -unknown-   NaN         basic            0
# 27             2010-01-22     FEMALE  32.0         basic            0
# 28             2010-01-13  -unknown-  35.0         basic            0
# 29             2010-01-19  -unknown-  37.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 213421                NaN  -unknown-   NaN         basic            0
# 213422                NaN  -unknown-   NaN         basic            0
# 213423                NaN     FEMALE  20.0      facebook           25
# 213424                NaN     FEMALE  32.0      facebook            0
# 213425                NaN     FEMALE  30.0      facebook            0
# 213426                NaN  -unknown-   NaN         basic            0
# 213427                NaN  -unknown-   NaN         basic            0
# 213428                NaN  -unknown-   NaN         basic           23
# 213429                NaN  -unknown-   NaN         basic           25
# 213430                NaN  -unknown-  19.0         basic            0
# 213431                NaN  -unknown-   NaN         basic            0
# 213432                NaN       MALE  31.0      facebook            0
# 213433                NaN  -unknown-   NaN         basic            0
# 213434                NaN  -unknown-   NaN         basic            0
# 213435                NaN  -unknown-   NaN         basic            0
# 213436                NaN  -unknown-   NaN         basic           25
# 213437                NaN  -unknown-   NaN         basic           23
# 213438                NaN  -unknown-   NaN         basic           25
# 213439         2015-03-16       MALE  43.0         basic            0
# 213440                NaN     FEMALE  24.0         basic           25
# 213441         2014-08-13     FEMALE  34.0         basic            0
# 213442                NaN  -unknown-   NaN         basic            0
# 213443         2014-07-13     FEMALE  36.0         basic            0
# 213444                NaN  -unknown-   NaN         basic            0
# 213445         2014-07-02     FEMALE  23.0         basic            0
# 213446                NaN       MALE  32.0         basic            0
# 213447                NaN  -unknown-   NaN         basic            0
# 213448                NaN  -unknown-  32.0         basic            0
# 213449                NaN  -unknown-   NaN         basic           25
# 213450                NaN  -unknown-   NaN         basic           25
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 0            en            direct             direct               untracked
# 1            en               seo             google               untracked
# 2            en            direct             direct               untracked
# 3            en            direct             direct               untracked
# 4            en            direct             direct               untracked
# 5            en             other              other                     omg
# 6            en             other         craigslist               untracked
# 7            en            direct             direct                     omg
# 8            en             other         craigslist               untracked
# 9            en             other         craigslist                     omg
# 10           en             other         craigslist               untracked
# 11           en             other         craigslist               untracked
# 12           en            direct             direct                     NaN
# 13           en             other         craigslist                  linked
# 14           en             other         craigslist               untracked
# 15           en            direct             direct               untracked
# 16           en             other         craigslist                     NaN
# 17           en             other         craigslist                     NaN
# 18           en               seo           facebook                     NaN
# 19           en            direct             direct               untracked
# 20           en            direct             direct                     NaN
# 21           en            direct             direct                  linked
# 22           en               seo             google               untracked
# 23           en             other         craigslist               untracked
# 24           en               seo             google               untracked
# 25           en             other         craigslist               untracked
# 26           en             other              other               untracked
# 27           en             other         craigslist               untracked
# 28           en            direct             direct                     NaN
# 29           en            direct             direct               untracked
# ...         ...               ...                ...                     ...
# 213421       en            direct             direct                  linked
# 213422       en            direct             direct               untracked
# 213423       en            direct             direct               untracked
# 213424       en            direct             direct                  linked
# 213425       en            direct             direct                  linked
# 213426       en            direct             direct               untracked
# 213427       en            direct             direct                  linked
# 213428       en            direct             direct               untracked
# 213429       en            direct             direct               untracked
# 213430       en            direct             direct                  linked
# 213431       en            direct             direct               untracked
# 213432       en            direct             direct           tracked-other
# 213433       en         sem-brand             google               untracked
# 213434       en               seo           facebook                 product
# 213435       en               seo             google               untracked
# 213436       en            direct             direct               untracked
# 213437       en            direct             direct               untracked
# 213438       en            direct             direct               untracked
# 213439       en            direct             direct               untracked
# 213440       en            direct             direct               untracked
# 213441       en            direct             direct                  linked
# 213442       en         sem-brand             google                     omg
# 213443       en         sem-brand             google                  linked
# 213444       en            direct             direct                  linked
# 213445       en         sem-brand             google                     omg
# 213446       en         sem-brand             google                     omg
# 213447       en            direct             direct                  linked
# 213448       en            direct             direct               untracked
# 213449       en             other              other           tracked-other
# 213450       en            direct             direct               untracked
#
#        signup_app first_device_type  first_browser country_destination
# 0             Web       Mac Desktop         Chrome                 NDF
# 1             Web       Mac Desktop         Chrome                 NDF
# 2             Web   Windows Desktop             IE                  US
# 3             Web       Mac Desktop        Firefox               other
# 4             Web       Mac Desktop         Chrome                  US
# 5             Web       Mac Desktop         Chrome                  US
# 6             Web       Mac Desktop         Safari                  US
# 7             Web       Mac Desktop         Safari                  US
# 8             Web       Mac Desktop         Safari                  US
# 9             Web       Mac Desktop        Firefox                  US
# 10            Web       Mac Desktop        Firefox                  US
# 11            Web            iPhone      -unknown-                 NDF
# 12            Web     Other/Unknown      -unknown-                  FR
# 13            Web       Mac Desktop        Firefox                 NDF
# 14            Web            iPhone  Mobile Safari                 NDF
# 15            Web   Windows Desktop         Chrome                  CA
# 16            Web     Other/Unknown      -unknown-                 NDF
# 17            Web     Other/Unknown      -unknown-                  US
# 18            Web     Other/Unknown      -unknown-                 NDF
# 19            Web       Mac Desktop         Chrome                  FR
# 20            Web     Other/Unknown      -unknown-                  US
# 21            Web       Mac Desktop         Chrome                  US
# 22            Web            iPhone      -unknown-                  US
# 23            Web       Mac Desktop         Safari                 NDF
# 24            Web       Mac Desktop        Firefox                 NDF
# 25            Web       Mac Desktop         Chrome                  FR
# 26            Web     Other/Unknown      -unknown-                 NDF
# 27            Web   Desktop (Other)         Chrome                  US
# 28            Web     Other/Unknown      -unknown-                  FR
# 29            Web    Android Tablet      -unknown-                  US
# ...           ...               ...            ...                 ...
# 213421        Web       Mac Desktop        Firefox                 NDF
# 213422        Web   Windows Desktop             IE                 NDF
# 213423        iOS            iPhone      -unknown-                 NDF
# 213424        Web   Windows Desktop         Chrome                 NDF
# 213425        Web   Windows Desktop         Chrome                 NDF
# 213426      Moweb     Android Phone  Chrome Mobile                 NDF
# 213427        Web   Desktop (Other)         Chrome                 NDF
# 213428    Android     Android Phone      -unknown-                 NDF
# 213429        iOS            iPhone      -unknown-                 NDF
# 213430        Web       Mac Desktop         Chrome                 NDF
# 213431        Web   Windows Desktop        Firefox                 NDF
# 213432        Web       Mac Desktop         Safari                 NDF
# 213433        Web              iPad  Mobile Safari                 NDF
# 213434        Web       Mac Desktop         Chrome                 NDF
# 213435        Web   Windows Desktop         Chrome                 NDF
# 213436        iOS            iPhone      -unknown-                 NDF
# 213437    Android    Android Tablet      -unknown-                 NDF
# 213438        iOS            iPhone      -unknown-                 NDF
# 213439        Web   Windows Desktop        Firefox                  US
# 213440        iOS            iPhone  Mobile Safari                 NDF
# 213441        Web       Mac Desktop         Chrome                  ES
# 213442        Web       Mac Desktop         Chrome                 NDF
# 213443        Web       Mac Desktop         Safari                  US
# 213444        Web   Windows Desktop         Chrome                 NDF
# 213445        Web   Windows Desktop             IE                  US
# 213446        Web       Mac Desktop         Safari                 NDF
# 213447        Web   Windows Desktop         Chrome                 NDF
# 213448        Web       Mac Desktop        Firefox                 NDF
# 213449        iOS            iPhone  Mobile Safari                 NDF
# 213450        iOS            iPhone      -unknown-                 NDF
#
# [213451 rows x 16 columns]

# %%
test_users
# Out:
#                id date_account_created  timestamp_first_active  \
# 0      5uwns89zht           2014-07-01          20140701000006
# 1      jtl0dijy2j           2014-07-01          20140701000051
# 2      xx0ulgorjt           2014-07-01          20140701000148
# 3      6c6puo6ix0           2014-07-01          20140701000215
# 4      czqhjk3yfe           2014-07-01          20140701000305
# 5      szx28ujmhf           2014-07-01          20140701000336
# 6      guenkfjcbq           2014-07-01          20140701000514
# 7      tkpq0mlugk           2014-07-01          20140701000649
# 8      3xtgd5p9dn           2014-07-01          20140701000837
# 9      md9aj22l5a           2014-07-01          20140701002245
# 10     gg3eswjxdf           2014-07-01          20140701002406
# 11     fyomoivygn           2014-07-01          20140701002531
# 12     iq4kkd5oan           2014-07-01          20140701002539
# 13     6k1xls6x5j           2014-07-01          20140701002912
# 14     jodmb2ok1f           2014-07-01          20140701003057
# 15     eq6fy0m4vc           2014-07-01          20140701003103
# 16     yq4i7nfh6l           2014-07-01          20140701003421
# 17     q5pibqdous           2014-07-01          20140701003533
# 18     i0sc6d3j8s           2014-07-01          20140701003723
# 19     br5mcrsqzn           2014-07-01          20140701004052
# 20     rddbczuxx1           2014-07-01          20140701004053
# 21     glck7hlmzz           2014-07-01          20140701004259
# 22     sxpkaxep8n           2014-07-01          20140701004343
# 23     sr4ntmalz2           2014-07-01          20140701004344
# 24     f6wueq1ccn           2014-07-01          20140701004359
# 25     ovc6nwn6mj           2014-07-01          20140701004654
# 26     n10skstp90           2014-07-01          20140701004748
# 27     5jrbdigmv4           2014-07-01          20140701004809
# 28     d45nngmojp           2014-07-01          20140701004817
# 29     y0frb6t1kq           2014-07-01          20140701005250
# ...           ...                  ...                     ...
# 62066  bsv2ev628t           2014-09-30          20140930231454
# 62067  06echc56pl           2014-09-30          20140930231518
# 62068  niqgaye2ov           2014-09-30          20140930231952
# 62069  61iwzuhw6e           2014-09-30          20140930232126
# 62070  gks02el96u           2014-09-30          20140930232237
# 62071  v4r1161l0r           2014-09-30          20140930232253
# 62072  p1clbqd0o6           2014-09-30          20140930232331
# 62073  ozb2z0km6l           2014-09-30          20140930232507
# 62074  w3e3sp6i70           2014-09-30          20140930232551
# 62075  q5bxbq0asg           2014-09-30          20140930232613
# 62076  1xa5t3t0la           2014-09-30          20140930233113
# 62077  zuvz7gfpjz           2014-09-30          20140930233305
# 62078  gpusl6ppgf           2014-09-30          20140930233535
# 62079  gpijioh4eh           2014-09-30          20140930233902
# 62080  3ptlvdxss9           2014-09-30          20140930234128
# 62081  f9a1ncjnrg           2014-09-30          20140930234425
# 62082  kofaz2kh70           2014-09-30          20140930234515
# 62083  6xrmom7hjo           2014-09-30          20140930234551
# 62084  cg9wqgnad2           2014-09-30          20140930234612
# 62085  jg618z94wo           2014-09-30          20140930234617
# 62086  u7lv3glv6y           2014-09-30          20140930234703
# 62087  o6ofmozucx           2014-09-30          20140930234751
# 62088  wcw7xggeqp           2014-09-30          20140930234904
# 62089  m22pw2pkxr           2014-09-30          20140930235000
# 62090  8yvhec201j           2014-09-30          20140930235019
# 62091  cv0na2lf5a           2014-09-30          20140930235232
# 62092  zp8xfonng8           2014-09-30          20140930235306
# 62093  fa6260ziny           2014-09-30          20140930235408
# 62094  87k0fy4ugm           2014-09-30          20140930235430
# 62095  9uqfg8txu3           2014-09-30          20140930235901
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN     FEMALE  35.0      facebook            0
# 1                     NaN  -unknown-   NaN         basic            0
# 2                     NaN  -unknown-   NaN         basic            0
# 3                     NaN  -unknown-   NaN         basic            0
# 4                     NaN  -unknown-   NaN         basic            0
# 5                     NaN     FEMALE  28.0         basic            0
# 6                     NaN       MALE  48.0         basic           25
# 7                     NaN  -unknown-   NaN         basic            0
# 8                     NaN  -unknown-   NaN         basic            0
# 9                     NaN  -unknown-   NaN         basic            0
# 10                    NaN  -unknown-   NaN         basic            0
# 11                    NaN     FEMALE  30.0         basic           25
# 12                    NaN       MALE  24.0      facebook            0
# 13                    NaN  -unknown-   NaN         basic            0
# 14                    NaN  -unknown-   NaN         basic            0
# 15                    NaN     FEMALE  56.0         basic            0
# 16                    NaN  -unknown-   NaN         basic            0
# 17                    NaN  -unknown-  30.0         basic            0
# 18                    NaN     FEMALE  33.0         basic            0
# 19                    NaN       MALE  31.0      facebook            0
# 20                    NaN     FEMALE  53.0         basic            0
# 21                    NaN  -unknown-   NaN         basic            0
# 22                    NaN       MALE  35.0      facebook            0
# 23                    NaN  -unknown-   NaN         basic            0
# 24                    NaN  -unknown-   NaN         basic            0
# 25                    NaN       MALE  34.0         basic            0
# 26                    NaN     FEMALE  25.0         basic            0
# 27                    NaN  -unknown-   NaN         basic            0
# 28                    NaN  -unknown-  27.0         basic            0
# 29                    NaN  -unknown-   NaN         basic            0
# ...                   ...        ...   ...           ...          ...
# 62066                 NaN  -unknown-   NaN        google           12
# 62067                 NaN     FEMALE  48.0         basic            0
# 62068                 NaN  -unknown-   NaN         basic            0
# 62069                 NaN     FEMALE  24.0      facebook           25
# 62070                 NaN     FEMALE  32.0      facebook            0
# 62071                 NaN  -unknown-   NaN         basic            0
# 62072                 NaN  -unknown-   NaN         basic           23
# 62073                 NaN  -unknown-   NaN         basic           23
# 62074                 NaN  -unknown-   NaN         basic            0
# 62075                 NaN     FEMALE  40.0      facebook            0
# 62076                 NaN       MALE  39.0      facebook            0
# 62077                 NaN  -unknown-   NaN         basic            0
# 62078                 NaN  -unknown-   NaN         basic            0
# 62079                 NaN       MALE  44.0         basic            0
# 62080                 NaN  -unknown-  39.0         basic            0
# 62081                 NaN     FEMALE  34.0      facebook           23
# 62082                 NaN  -unknown-   NaN         basic            0
# 62083                 NaN       MALE  40.0      facebook           23
# 62084                 NaN       MALE  27.0      facebook            0
# 62085                 NaN     FEMALE  24.0      facebook            0
# 62086                 NaN  -unknown-   NaN         basic           25
# 62087                 NaN       MALE  55.0         basic            0
# 62088                 NaN  -unknown-  34.0         basic            0
# 62089                 NaN       MALE  32.0         basic            0
# 62090                 NaN  -unknown-   NaN         basic            0
# 62091                 NaN  -unknown-  31.0         basic            0
# 62092                 NaN  -unknown-   NaN         basic           23
# 62093                 NaN  -unknown-   NaN         basic            0
# 62094                 NaN  -unknown-   NaN         basic            0
# 62095                 NaN     FEMALE  49.0         basic            0
#
#       language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 0           en            direct             direct               untracked
# 1           en            direct             direct               untracked
# 2           en            direct             direct                  linked
# 3           en            direct             direct                  linked
# 4           en            direct             direct               untracked
# 5           en         sem-brand             google                     omg
# 6           en            direct             direct               untracked
# 7           en            direct             direct               untracked
# 8           en            direct             direct               untracked
# 9           en     sem-non-brand             google                     omg
# 10          en            direct             direct               untracked
# 11          en            direct             direct               untracked
# 12          en            direct             direct                  linked
# 13          en            direct             direct                  linked
# 14          en            direct             direct               untracked
# 15          en            direct             direct                  linked
# 16          en            direct             direct               untracked
# 17          en            direct             direct                  linked
# 18          en            direct             direct                     omg
# 19          en               seo             google                  linked
# 20          en         sem-brand             google                  linked
# 21          en            direct             direct               untracked
# 22          en               seo             google                  linked
# 23          en            direct             direct               untracked
# 24          en     sem-non-brand             google                     omg
# 25          en            direct             direct                  linked
# 26          en         sem-brand             google                     omg
# 27          en         sem-brand               bing                     omg
# 28          en            direct             direct                 product
# 29          en         sem-brand             google                  linked
# ...        ...               ...                ...                     ...
# 62066       en            direct             direct               untracked
# 62067       en            direct             direct               untracked
# 62068       en               seo             google               untracked
# 62069       en            direct             direct               untracked
# 62070       en               seo           facebook               untracked
# 62071       en            direct             direct               untracked
# 62072       en            direct             direct               untracked
# 62073       en            direct             direct               untracked
# 62074       en            direct             direct                  linked
# 62075       en         sem-brand             google                     omg
# 62076       en               seo           facebook               untracked
# 62077       en               seo             google               untracked
# 62078       en               seo             google               untracked
# 62079       en               seo             google                  linked
# 62080       en               seo             google                  linked
# 62081       en            direct             direct               untracked
# 62082       en               seo             google               untracked
# 62083       en            direct             direct               untracked
# 62084       en            direct             direct               untracked
# 62085       en            direct             direct                  linked
# 62086       en            direct             direct               untracked
# 62087       en         sem-brand             google                     omg
# 62088       en            direct             direct               untracked
# 62089       en            direct             direct                  linked
# 62090       en               seo              yahoo                  linked
# 62091       en            direct             direct               untracked
# 62092       ko            direct             direct               untracked
# 62093       de            direct             direct                  linked
# 62094       en         sem-brand             google                     omg
# 62095       en             other              other           tracked-other
#
#       signup_app first_device_type  first_browser country_destination
# 0          Moweb            iPhone  Mobile Safari                 NDF
# 1          Moweb            iPhone  Mobile Safari                 NDF
# 2            Web   Windows Desktop         Chrome                 NDF
# 3            Web   Windows Desktop             IE                 NDF
# 4            Web       Mac Desktop         Safari                 NDF
# 5            Web   Windows Desktop         Chrome                 NDF
# 6            iOS            iPhone      -unknown-                 NDF
# 7            Web       Mac Desktop         Chrome                 NDF
# 8            Web       Mac Desktop         Chrome                 NDF
# 9            Web   Windows Desktop        Firefox                 NDF
# 10           Web   Windows Desktop        Firefox                 NDF
# 11           iOS            iPhone      -unknown-                 NDF
# 12           Web       Mac Desktop         Safari                 NDF
# 13           Web       Mac Desktop         Chrome                 NDF
# 14         Moweb              iPad  Mobile Safari                 NDF
# 15           Web   Windows Desktop         Chrome                 NDF
# 16           Web            iPhone  Mobile Safari                 NDF
# 17           Web   Windows Desktop         Chrome                 NDF
# 18           Web    Android Tablet             IE                 NDF
# 19           Web   Windows Desktop         Chrome                 NDF
# 20           Web       Mac Desktop         Safari                 NDF
# 21           Web       Mac Desktop        Firefox                 NDF
# 22           Web   Windows Desktop         Chrome                 NDF
# 23           Web       Mac Desktop        Firefox                 NDF
# 24           Web   Windows Desktop         Chrome                 NDF
# 25         Moweb            iPhone  Mobile Safari                 NDF
# 26           Web       Mac Desktop         Chrome                 NDF
# 27           Web   Windows Desktop             IE                 NDF
# 28           Web       Mac Desktop         Chrome                 NDF
# 29           Web              iPad  Mobile Safari                 NDF
# ...          ...               ...            ...                 ...
# 62066    Android     Android Phone      -unknown-                 NDF
# 62067        Web       Mac Desktop         Safari                 NDF
# 62068        Web       Mac Desktop        Firefox                 NDF
# 62069        iOS            iPhone      -unknown-                 NDF
# 62070        Web              iPad  Mobile Safari                 NDF
# 62071      Moweb     Android Phone  Chrome Mobile                 NDF
# 62072    Android     Android Phone      -unknown-                 NDF
# 62073    Android     Android Phone      -unknown-                 NDF
# 62074      Moweb            iPhone  Mobile Safari                 NDF
# 62075        Web   Windows Desktop        Firefox                 NDF
# 62076        Web            iPhone  Mobile Safari                 NDF
# 62077        Web       Mac Desktop        Firefox                 NDF
# 62078        Web              iPad  Mobile Safari                 NDF
# 62079        Web       Mac Desktop         Chrome                 NDF
# 62080        Web   Windows Desktop        Firefox                 NDF
# 62081    Android     Android Phone      -unknown-                 NDF
# 62082        Web       Mac Desktop         Safari                 NDF
# 62083    Android     Android Phone      -unknown-                 NDF
# 62084        Web       Mac Desktop        Firefox                 NDF
# 62085        Web            iPhone  Mobile Safari                 NDF
# 62086        iOS            iPhone      -unknown-                 NDF
# 62087        Web   Windows Desktop        Firefox                 NDF
# 62088        Web       Mac Desktop         Chrome                 NDF
# 62089        Web   Windows Desktop         Chrome                 NDF
# 62090        Web   Windows Desktop         Chrome                 NDF
# 62091        Web   Windows Desktop             IE                 NDF
# 62092    Android     Android Phone      -unknown-                 NDF
# 62093        Web   Windows Desktop        Firefox                 NDF
# 62094        Web       Mac Desktop         Safari                 NDF
# 62095        Web   Windows Desktop         Chrome                 NDF
#
# [62096 rows x 16 columns]

# %% [markdown]
# # Merging
# From the analysis we can deduce that the test_users is an extension from the train_users dataset. Therefore we can merge the datasets to streamline the data cleaning phase.

# %%
# Adding NDF value to null
test_users["country_destination"]= 'NDF'

# Merge train and test users
frames = [train_users, test_users]

# Creating new merged data frane that avoids the "copy of slice from DataFrame" error
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
users = pd.DataFrame(pd.concat((frames), axis=0, ignore_index=True))

# %% [markdown]
# # Cleaning & Prepartion for Normalization

# %% [markdown]
# ### Basic Analysis of Data
# From line ## to ## we are performing a basic analysis of data to identify patterns and/or irrelevant parts.
#
# * .shape >> return the number of rows and columns in the data set
# * .describe >> returns statistics about the numerical columns in a dataset

# %%
users
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28          20090319043255
# 1       820tgsjxq7           2011-05-25          20090523174809
# 2       4ft3gnwmtx           2010-09-28          20090609231247
# 3       bjjt8pjhuk           2011-12-05          20091031060129
# 4       87mebub9p4           2010-09-14          20091208061105
# 5       osr2jwljor           2010-01-01          20100101215619
# 6       lsw9q7uk0j           2010-01-02          20100102012558
# 7       0d01nltbrs           2010-01-03          20100103191905
# 8       a1vcnhxeij           2010-01-04          20100104004211
# 9       6uh8zyj2gn           2010-01-04          20100104023758
# 10      yuuqmid2rp           2010-01-04          20100104194251
# 11      om1ss59ys8           2010-01-05          20100105051812
# 12      k6np330cm1           2010-01-05          20100105060859
# 13      dy3rgx56cu           2010-01-05          20100105083259
# 14      ju3h98ch3w           2010-01-07          20100107055820
# 15      v4d5rl22px           2010-01-07          20100107204555
# 16      2dwbwkx056           2010-01-07          20100107215125
# 17      frhre329au           2010-01-07          20100107224625
# 18      cxlg85pg1r           2010-01-08          20100108015641
# 19      gdka1q5ktd           2010-01-10          20100110010817
# 20      qdubonn3uk           2010-01-10          20100110152120
# 21      qsibmuz9sx           2010-01-10          20100110220941
# 22      80f7dwscrn           2010-01-11          20100111031438
# 23      jha93x042q           2010-01-11          20100111224015
# 24      7i49vnuav6           2010-01-11          20100111230808
# 25      al8bcetz0g           2010-01-12          20100112131444
# 26      bjg0m5otl3           2010-01-12          20100112155420
# 27      hfrl5gle36           2010-01-12          20100112205949
# 28      tp6x3md0n4           2010-01-13          20100113044650
# 29      hql77nu2lk           2010-01-13          20100113064333
# ...            ...                  ...                     ...
# 275517  bsv2ev628t           2014-09-30          20140930231454
# 275518  06echc56pl           2014-09-30          20140930231518
# 275519  niqgaye2ov           2014-09-30          20140930231952
# 275520  61iwzuhw6e           2014-09-30          20140930232126
# 275521  gks02el96u           2014-09-30          20140930232237
# 275522  v4r1161l0r           2014-09-30          20140930232253
# 275523  p1clbqd0o6           2014-09-30          20140930232331
# 275524  ozb2z0km6l           2014-09-30          20140930232507
# 275525  w3e3sp6i70           2014-09-30          20140930232551
# 275526  q5bxbq0asg           2014-09-30          20140930232613
# 275527  1xa5t3t0la           2014-09-30          20140930233113
# 275528  zuvz7gfpjz           2014-09-30          20140930233305
# 275529  gpusl6ppgf           2014-09-30          20140930233535
# 275530  gpijioh4eh           2014-09-30          20140930233902
# 275531  3ptlvdxss9           2014-09-30          20140930234128
# 275532  f9a1ncjnrg           2014-09-30          20140930234425
# 275533  kofaz2kh70           2014-09-30          20140930234515
# 275534  6xrmom7hjo           2014-09-30          20140930234551
# 275535  cg9wqgnad2           2014-09-30          20140930234612
# 275536  jg618z94wo           2014-09-30          20140930234617
# 275537  u7lv3glv6y           2014-09-30          20140930234703
# 275538  o6ofmozucx           2014-09-30          20140930234751
# 275539  wcw7xggeqp           2014-09-30          20140930234904
# 275540  m22pw2pkxr           2014-09-30          20140930235000
# 275541  8yvhec201j           2014-09-30          20140930235019
# 275542  cv0na2lf5a           2014-09-30          20140930235232
# 275543  zp8xfonng8           2014-09-30          20140930235306
# 275544  fa6260ziny           2014-09-30          20140930235408
# 275545  87k0fy4ugm           2014-09-30          20140930235430
# 275546  9uqfg8txu3           2014-09-30          20140930235901
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN  -unknown-   NaN      facebook            0
# 1                     NaN       MALE  38.0      facebook            0
# 2              2010-08-02     FEMALE  56.0         basic            3
# 3              2012-09-08     FEMALE  42.0      facebook            0
# 4              2010-02-18  -unknown-  41.0         basic            0
# 5              2010-01-02  -unknown-   NaN         basic            0
# 6              2010-01-05     FEMALE  46.0         basic            0
# 7              2010-01-13     FEMALE  47.0         basic            0
# 8              2010-07-29     FEMALE  50.0         basic            0
# 9              2010-01-04  -unknown-  46.0         basic            0
# 10             2010-01-06     FEMALE  36.0         basic            0
# 11                    NaN     FEMALE  47.0         basic            0
# 12             2010-01-18  -unknown-   NaN         basic            0
# 13                    NaN     FEMALE  37.0         basic            0
# 14                    NaN     FEMALE  36.0         basic            0
# 15             2010-01-08     FEMALE  33.0         basic            0
# 16                    NaN  -unknown-   NaN         basic            0
# 17             2010-01-09  -unknown-  31.0         basic            0
# 18                    NaN  -unknown-   NaN         basic            0
# 19             2010-01-10     FEMALE  29.0         basic            0
# 20             2010-01-18  -unknown-   NaN         basic            0
# 21             2010-01-11       MALE  30.0         basic            0
# 22             2010-01-11  -unknown-  40.0         basic            0
# 23                    NaN  -unknown-   NaN         basic            0
# 24                    NaN     FEMALE  40.0         basic            0
# 25             2010-01-15     FEMALE  26.0         basic            0
# 26                    NaN  -unknown-   NaN         basic            0
# 27             2010-01-22     FEMALE  32.0         basic            0
# 28             2010-01-13  -unknown-  35.0         basic            0
# 29             2010-01-19  -unknown-  37.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 275517                NaN  -unknown-   NaN        google           12
# 275518                NaN     FEMALE  48.0         basic            0
# 275519                NaN  -unknown-   NaN         basic            0
# 275520                NaN     FEMALE  24.0      facebook           25
# 275521                NaN     FEMALE  32.0      facebook            0
# 275522                NaN  -unknown-   NaN         basic            0
# 275523                NaN  -unknown-   NaN         basic           23
# 275524                NaN  -unknown-   NaN         basic           23
# 275525                NaN  -unknown-   NaN         basic            0
# 275526                NaN     FEMALE  40.0      facebook            0
# 275527                NaN       MALE  39.0      facebook            0
# 275528                NaN  -unknown-   NaN         basic            0
# 275529                NaN  -unknown-   NaN         basic            0
# 275530                NaN       MALE  44.0         basic            0
# 275531                NaN  -unknown-  39.0         basic            0
# 275532                NaN     FEMALE  34.0      facebook           23
# 275533                NaN  -unknown-   NaN         basic            0
# 275534                NaN       MALE  40.0      facebook           23
# 275535                NaN       MALE  27.0      facebook            0
# 275536                NaN     FEMALE  24.0      facebook            0
# 275537                NaN  -unknown-   NaN         basic           25
# 275538                NaN       MALE  55.0         basic            0
# 275539                NaN  -unknown-  34.0         basic            0
# 275540                NaN       MALE  32.0         basic            0
# 275541                NaN  -unknown-   NaN         basic            0
# 275542                NaN  -unknown-  31.0         basic            0
# 275543                NaN  -unknown-   NaN         basic           23
# 275544                NaN  -unknown-   NaN         basic            0
# 275545                NaN  -unknown-   NaN         basic            0
# 275546                NaN     FEMALE  49.0         basic            0
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 0            en            direct             direct               untracked
# 1            en               seo             google               untracked
# 2            en            direct             direct               untracked
# 3            en            direct             direct               untracked
# 4            en            direct             direct               untracked
# 5            en             other              other                     omg
# 6            en             other         craigslist               untracked
# 7            en            direct             direct                     omg
# 8            en             other         craigslist               untracked
# 9            en             other         craigslist                     omg
# 10           en             other         craigslist               untracked
# 11           en             other         craigslist               untracked
# 12           en            direct             direct                     NaN
# 13           en             other         craigslist                  linked
# 14           en             other         craigslist               untracked
# 15           en            direct             direct               untracked
# 16           en             other         craigslist                     NaN
# 17           en             other         craigslist                     NaN
# 18           en               seo           facebook                     NaN
# 19           en            direct             direct               untracked
# 20           en            direct             direct                     NaN
# 21           en            direct             direct                  linked
# 22           en               seo             google               untracked
# 23           en             other         craigslist               untracked
# 24           en               seo             google               untracked
# 25           en             other         craigslist               untracked
# 26           en             other              other               untracked
# 27           en             other         craigslist               untracked
# 28           en            direct             direct                     NaN
# 29           en            direct             direct               untracked
# ...         ...               ...                ...                     ...
# 275517       en            direct             direct               untracked
# 275518       en            direct             direct               untracked
# 275519       en               seo             google               untracked
# 275520       en            direct             direct               untracked
# 275521       en               seo           facebook               untracked
# 275522       en            direct             direct               untracked
# 275523       en            direct             direct               untracked
# 275524       en            direct             direct               untracked
# 275525       en            direct             direct                  linked
# 275526       en         sem-brand             google                     omg
# 275527       en               seo           facebook               untracked
# 275528       en               seo             google               untracked
# 275529       en               seo             google               untracked
# 275530       en               seo             google                  linked
# 275531       en               seo             google                  linked
# 275532       en            direct             direct               untracked
# 275533       en               seo             google               untracked
# 275534       en            direct             direct               untracked
# 275535       en            direct             direct               untracked
# 275536       en            direct             direct                  linked
# 275537       en            direct             direct               untracked
# 275538       en         sem-brand             google                     omg
# 275539       en            direct             direct               untracked
# 275540       en            direct             direct                  linked
# 275541       en               seo              yahoo                  linked
# 275542       en            direct             direct               untracked
# 275543       ko            direct             direct               untracked
# 275544       de            direct             direct                  linked
# 275545       en         sem-brand             google                     omg
# 275546       en             other              other           tracked-other
#
#        signup_app first_device_type  first_browser country_destination
# 0             Web       Mac Desktop         Chrome                 NDF
# 1             Web       Mac Desktop         Chrome                 NDF
# 2             Web   Windows Desktop             IE                  US
# 3             Web       Mac Desktop        Firefox               other
# 4             Web       Mac Desktop         Chrome                  US
# 5             Web       Mac Desktop         Chrome                  US
# 6             Web       Mac Desktop         Safari                  US
# 7             Web       Mac Desktop         Safari                  US
# 8             Web       Mac Desktop         Safari                  US
# 9             Web       Mac Desktop        Firefox                  US
# 10            Web       Mac Desktop        Firefox                  US
# 11            Web            iPhone      -unknown-                 NDF
# 12            Web     Other/Unknown      -unknown-                  FR
# 13            Web       Mac Desktop        Firefox                 NDF
# 14            Web            iPhone  Mobile Safari                 NDF
# 15            Web   Windows Desktop         Chrome                  CA
# 16            Web     Other/Unknown      -unknown-                 NDF
# 17            Web     Other/Unknown      -unknown-                  US
# 18            Web     Other/Unknown      -unknown-                 NDF
# 19            Web       Mac Desktop         Chrome                  FR
# 20            Web     Other/Unknown      -unknown-                  US
# 21            Web       Mac Desktop         Chrome                  US
# 22            Web            iPhone      -unknown-                  US
# 23            Web       Mac Desktop         Safari                 NDF
# 24            Web       Mac Desktop        Firefox                 NDF
# 25            Web       Mac Desktop         Chrome                  FR
# 26            Web     Other/Unknown      -unknown-                 NDF
# 27            Web   Desktop (Other)         Chrome                  US
# 28            Web     Other/Unknown      -unknown-                  FR
# 29            Web    Android Tablet      -unknown-                  US
# ...           ...               ...            ...                 ...
# 275517    Android     Android Phone      -unknown-                 NDF
# 275518        Web       Mac Desktop         Safari                 NDF
# 275519        Web       Mac Desktop        Firefox                 NDF
# 275520        iOS            iPhone      -unknown-                 NDF
# 275521        Web              iPad  Mobile Safari                 NDF
# 275522      Moweb     Android Phone  Chrome Mobile                 NDF
# 275523    Android     Android Phone      -unknown-                 NDF
# 275524    Android     Android Phone      -unknown-                 NDF
# 275525      Moweb            iPhone  Mobile Safari                 NDF
# 275526        Web   Windows Desktop        Firefox                 NDF
# 275527        Web            iPhone  Mobile Safari                 NDF
# 275528        Web       Mac Desktop        Firefox                 NDF
# 275529        Web              iPad  Mobile Safari                 NDF
# 275530        Web       Mac Desktop         Chrome                 NDF
# 275531        Web   Windows Desktop        Firefox                 NDF
# 275532    Android     Android Phone      -unknown-                 NDF
# 275533        Web       Mac Desktop         Safari                 NDF
# 275534    Android     Android Phone      -unknown-                 NDF
# 275535        Web       Mac Desktop        Firefox                 NDF
# 275536        Web            iPhone  Mobile Safari                 NDF
# 275537        iOS            iPhone      -unknown-                 NDF
# 275538        Web   Windows Desktop        Firefox                 NDF
# 275539        Web       Mac Desktop         Chrome                 NDF
# 275540        Web   Windows Desktop         Chrome                 NDF
# 275541        Web   Windows Desktop         Chrome                 NDF
# 275542        Web   Windows Desktop             IE                 NDF
# 275543    Android     Android Phone      -unknown-                 NDF
# 275544        Web   Windows Desktop        Firefox                 NDF
# 275545        Web       Mac Desktop         Safari                 NDF
# 275546        Web   Windows Desktop         Chrome                 NDF
#
# [275547 rows x 16 columns]

# %%
# Updating the users dataframe column that contains gender with values.
# Unknown: 0
# Male: 1
# Female: 2
users.gender.replace('-unknown-',0, inplace=True)
users.gender.replace('MALE',1, inplace=True)
users.gender.replace('FEMALE',2, inplace=True)

# %%
#Displays the travel percentage of the male and females to the various countries
women = sum(users['gender'] == 2)
men = sum(users['gender'] == 1)

female_destinations = users.loc[users['gender'] == 2, 'country_destination'].value_counts() / women * 100
male_destinations = users.loc[users['gender'] == 1, 'country_destination'].value_counts() / men * 100

# Bar width
width = 0.4

male_destinations.plot(kind='bar', width=width, color='#4DD3C9', position=0, label='Male', rot=0)
female_destinations.plot(kind='bar', width=width, color='#FFA35D', position=1, label='Female', rot=0)

plt.legend()
plt.xlabel('Destination Country')
plt.ylabel('Percentage')

sns.despine()
plt.show()

# %%
# Sending solution to output file
my_solution = pd.DataFrame(users)
my_solution.to_csv("my_solution_one.csv", index_label = ["index"])
